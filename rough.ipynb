# %%
from src.data_loader import load_data, validate_data,preprocess_data, get_summary_stats, get_segment_analysis, get_quarterly_trends, get_rep_performance, create_heatmap_data

# %%
df = load_data()
df.head()
# Out:
#   deal_id created_date closed_date sales_rep_id    industry         region  \
# 0  D00001   2023-11-24  2023-12-15       rep_22        SaaS  North America
# 1  D00002   2023-01-17  2023-01-27        rep_7        SaaS          India
# 2  D00003   2023-10-29  2023-12-10        rep_5  HealthTech           APAC
# 3  D00004   2023-07-14  2023-08-02       rep_18     FinTech          India
# 4  D00005   2024-02-29  2024-05-26        rep_2  HealthTech           APAC
#
#   product_type lead_source   deal_stage  deal_amount  sales_cycle_days outcome
# 0   Enterprise    Referral    Qualified         4253                21     Won
# 1         Core    Referral       Closed         3905                10     Won
# 2         Core     Inbound     Proposal        10615                42    Lost
# 3         Core     Partner  Negotiation         4817                19     Won
# 4         Core    Outbound    Qualified        45203                87    Lost

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   deal_id           5000 non-null   object
#  1   created_date      5000 non-null   object
#  2   closed_date       5000 non-null   object
#  3   sales_rep_id      5000 non-null   object
#  4   industry          5000 non-null   object
#  5   region            5000 non-null   object
#  6   product_type      5000 non-null   object
#  7   lead_source       5000 non-null   object
#  8   deal_stage        5000 non-null   object
#  9   deal_amount       5000 non-null   int64
#  10  sales_cycle_days  5000 non-null   int64
#  11  outcome           5000 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 468.9+ KB

# %%
validate_data(df)
# Out:
# {'total_rows': 5000,
#  'total_columns': 12,
#  'missing_values': {'deal_id': 0,
#   'created_date': 0,
#   'closed_date': 0,
#   'sales_rep_id': 0,
#   'industry': 0,
#   'region': 0,
#   'product_type': 0,
#   'lead_source': 0,
#   'deal_stage': 0,
#   'deal_amount': 0,
#   'sales_cycle_days': 0,
#   'outcome': 0},
#  'duplicates': np.int64(0),
#  'date_range': {'created_min': '2023-01-01',
#   'created_max': '2024-03-26',
#   'closed_min': '2023-01-11',
#   'closed_max': '2024-07-20'},
#  'unique_values': {'industries': 5,
#   'regions': 4,
#   'product_types': 3,
#   'lead_sources': 4,
#   'sales_reps': 25,
#   'deal_stages': 5},
#  'outcome_distribution': {'Lost': 2737, 'Won': 2263},
#  'is_valid': True}

# %%
prep = preprocess_data(df)
prep.head()
# Out:
#   deal_id created_date closed_date sales_rep_id    industry         region  \
# 0  D00001   2023-11-24  2023-12-15       rep_22        SaaS  North America
# 1  D00002   2023-01-17  2023-01-27        rep_7        SaaS          India
# 2  D00003   2023-10-29  2023-12-10        rep_5  HealthTech           APAC
# 3  D00004   2023-07-14  2023-08-02       rep_18     FinTech          India
# 4  D00005   2024-02-29  2024-05-26        rep_2  HealthTech           APAC
#
#   product_type lead_source   deal_stage  deal_amount  ...  created_month  \
# 0   Enterprise    Referral    Qualified         4253  ...             11
# 1         Core    Referral       Closed         3905  ...              1
# 2         Core     Inbound     Proposal        10615  ...             10
# 3         Core     Partner  Negotiation         4817  ...              7
# 4         Core    Outbound    Qualified        45203  ...              2
#
#   created_quarter  created_year_quarter  closed_year  closed_month  \
# ...

# %%
get_summary_stats(prep)
# Out:
# {'total_deals': 5000,
#  'won_deals': np.int64(2263),
#  'lost_deals': np.int64(2737),
#  'overall_win_rate': np.float64(45.26),
#  'total_revenue_won': np.int64(60589278),
#  'total_revenue_lost': np.int64(70843186),
#  'avg_deal_size': np.float64(26286.4928),
#  'avg_deal_size_won': np.float64(26773.874502872295),
#  'avg_deal_size_lost': np.float64(25883.516989404456),
#  'avg_sales_cycle': np.float64(63.7518),
#  'avg_sales_cycle_won': np.float64(63.17322138753867),
#  'avg_sales_cycle_lost': np.float64(64.230179028133),
#  'median_deal_size': np.float64(14171.5),
#  'median_sales_cycle': np.float64(64.0)}

# %%
get_quarterly_trends(prep)
# Out:
#   closed_year_quarter  total_deals  won_deals  total_revenue  avg_deal_size  \
# 0              2023Q1          328        146        7689967   23445.021341
# 1              2023Q2          973        438       24880389   25570.800617
# 2              2023Q3         1016        435       27899635   27460.270669
# 3              2023Q4         1027        488       26799813   26095.241480
# 4              2024Q1          990        462       26413879   26680.685859
# 5              2024Q2          637        279       17009398   26702.351648
# 6              2024Q3           29         15         739383   25495.965517
#
#    avg_cycle_days  win_rate  revenue_won  win_rate_change  revenue_change_pct
# 0       35.795732     44.51      3565155              NaN                 NaN
# 1       61.382323     45.02     10990875             0.51          208.286035
# 2       64.538386     42.81     12822748            -2.21           16.667217
# ...
